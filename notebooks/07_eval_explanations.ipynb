# %% [markdown]
# # Stage 7: Evaluate Explanations
#
# Use this notebook to load saved saliency maps, run insertion and deletion evaluation, compute AUC values, and summarize results across conditions.
